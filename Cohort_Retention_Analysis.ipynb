# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgaprasad-77/Cohort-Retention-Analysis/blob/main/Cohort_Retention_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import matplotlib.colors as colors

# %% [markdown]
# Importing the Excel File

# %%
data = pd.read_excel('/content/drive/MyDrive/Online Retail.xlsx')

# %%
data.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %% [markdown]
# Creating New Date Column with proper Date Format using Pandas

# %%
data['InvoiceDat'] = pd.to_datetime(data.InvoiceDate, format='%Y-%m-%d')

# %%
data
# Out:
#        InvoiceNo StockCode  ...         Country          InvoiceDat
# 0         536365    85123A  ...  United Kingdom 2010-12-01 08:26:00
# 1         536365     71053  ...  United Kingdom 2010-12-01 08:26:00
# 2         536365    84406B  ...  United Kingdom 2010-12-01 08:26:00
# 3         536365    84029G  ...  United Kingdom 2010-12-01 08:26:00
# 4         536365    84029E  ...  United Kingdom 2010-12-01 08:26:00
# ...          ...       ...  ...             ...                 ...
# 541904    581587     22613  ...          France 2011-12-09 12:50:00
# 541905    581587     22899  ...          France 2011-12-09 12:50:00
# 541906    581587     23254  ...          France 2011-12-09 12:50:00
# 541907    581587     23255  ...          France 2011-12-09 12:50:00
# 541908    581587     22138  ...          France 2011-12-09 12:50:00
#
# [541909 rows x 9 columns]

# %%
def get_date(data,column):
  year =  data[column].dt.year
  month = data[column].dt.month
  day = data[column].dt.day
  return year,month,day

# %%
txn_year,txn_month, _ = get_date(data,'InvoiceDat')

cohort_year,cohort_month, _ = get_date(data,"InvoiceDat")

year_diff = txn_year - cohort_year

month_diff = txn_month - cohort_month

data['Cohortindex'] = year_diff * 12 + month_diff+1

# %%
data['order_month'] = data['InvoiceDat'].dt.to_period('M')

# %%
cohort_data = data.groupby(['order_month','Cohortindex' ])['CustomerID'].apply(pd.Series.nunique).reset_index()

# %%
data['cohort'] = data.groupby('CustomerID')['InvoiceDat'] \
                 .transform('min') \
                 .dt.to_period('M')

# %%
data
# Out:
#        InvoiceNo StockCode  ... order_month   cohort
# 0         536365    85123A  ...     2010-12  2010-12
# 1         536365     71053  ...     2010-12  2010-12
# 2         536365    84406B  ...     2010-12  2010-12
# 3         536365    84029G  ...     2010-12  2010-12
# 4         536365    84029E  ...     2010-12  2010-12
# ...          ...       ...  ...         ...      ...
# 541904    581587     22613  ...     2011-12  2011-08
# 541905    581587     22899  ...     2011-12  2011-08
# 541906    581587     23254  ...     2011-12  2011-08
# 541907    581587     23255  ...     2011-12  2011-08
# 541908    581587     22138  ...     2011-12  2011-08
#
# [541909 rows x 12 columns]

# %%
from operator import attrgetter

# %%
df_cohort = data.groupby(['cohort', 'order_month']) \
              .agg(n_customers=('CustomerID', 'nunique')) \
              .reset_index(drop=False)
df_cohort['period_number'] = (df_cohort.order_month - df_cohort.cohort).apply(attrgetter('n'))

# %%
cohort_pivot = df_cohort.pivot_table(index = 'cohort',
                                     columns = 'period_number',
                                     values = 'n_customers')

# %%
cohort_pivot
# Out:
# period_number     0      1      2      3   ...     9      10     11     12
# cohort                                     ...
# 2010-12        948.0  362.0  317.0  367.0  ...  374.0  354.0  474.0  260.0
# 2011-01        421.0  101.0  119.0  102.0  ...  146.0  155.0   63.0    NaN
# 2011-02        380.0   94.0   73.0  106.0  ...  119.0   35.0    NaN    NaN
# 2011-03        440.0   84.0  112.0   96.0  ...   39.0    NaN    NaN    NaN
# 2011-04        299.0   68.0   66.0   63.0  ...    NaN    NaN    NaN    NaN
# 2011-05        279.0   66.0   48.0   48.0  ...    NaN    NaN    NaN    NaN
# 2011-06        235.0   49.0   44.0   64.0  ...    NaN    NaN    NaN    NaN
# 2011-07        191.0   40.0   39.0   44.0  ...    NaN    NaN    NaN    NaN
# 2011-08        167.0   42.0   42.0   42.0  ...    NaN    NaN    NaN    NaN
# 2011-09        298.0   89.0   97.0   36.0  ...    NaN    NaN    NaN    NaN
# 2011-10        352.0   93.0   46.0    NaN  ...    NaN    NaN    NaN    NaN
# ...

# %%
cohort_size = cohort_pivot.iloc[:,0]
retention_matrix = cohort_pivot.divide(cohort_size, axis = 0)

# %%
import matplotlib.colors as colors

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(12, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})
    
    # retention matrix
    sns.heatmap(retention_matrix, 
                mask=retention_matrix.isnull(), 
                annot=True, 
                fmt='.0%', 
                cmap='RdYlGn', 
                ax=ax[1])
    ax[1].set_title('Monthly Cohorts: User Retention', fontsize=16)
    ax[1].set(xlabel='# of periods',
              ylabel='')

    # cohort size
    cohort_size_df = pd.DataFrame(cohort_size).rename(columns={0: 'cohort_size'})
    white_cmap = colors.ListedColormap(['white'])
    sns.heatmap(cohort_size_df, 
                annot=True, 
                cbar=False, 
                fmt='g', 
                cmap=white_cmap, 
                ax=ax[0])

    fig.tight_layout()
